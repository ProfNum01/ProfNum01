# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfNum01/ProfNum01/blob/main/Stocks_yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sure, here is a Python program that can be used to enhance pictures:

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Function to fetch stock data
def fetch_stock_data(stock_symbol, start_date, end_date):
    stock_data = yf.download(stock_symbol, start=start_date, end=end_date)
    return stock_data

# Function to preprocess the data
def preprocess_data(data, column_name):
    dataset = data[column_name].values
    dataset = dataset.astype('float32')
    dataset = np.reshape(dataset, (-1, 1))
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(dataset)
    return dataset, scaler

# Function to create input and output sequences for the LSTM model
def create_sequences(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        dataX.append(dataset[i:(i + look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Function to build and train the LSTM model
def build_and_train_model(trainX, trainY, look_back):
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, look_back)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
    return model

# Function to predict the next day's stock price
def predict_next_day(model, dataset, look_back, scaler):
    last_sequence = dataset[-look_back:]
    last_sequence = np.reshape(last_sequence, (1, 1, look_back))
    next_day_prediction = model.predict(last_sequence)
    next_day_prediction = scaler.inverse_transform(next_day_prediction)
    return next_day_prediction[0][0]

# Define the stock symbols, date range, and column name
stock_symbols = ['AAPL', 'GOOGL', 'MSFT']  # Add more stock symbols as needed
start_date = '2020-01-01'
end_date = '2023-05-26'
column_name = 'Close'

# Fetch stock data and predict the next day's stock price
stock_predictions = {}
for stock_symbol in stock_symbols:
    stock_data = fetch_stock_data(stock_symbol, start_date, end_date)
    dataset, scaler = preprocess_data(stock_data, column_name)
    look_back = 3
    trainX, trainY = create_sequences(dataset, look_back)
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    model = build_and_train_model(trainX, trainY, look_back)
    next_day_prediction = predict_next_day(model, dataset, look_back, scaler)
    stock_predictions[stock_symbol] = next_day_prediction

# Find the winning stock with the highest predicted price
winning_stock = max(stock_predictions, key=stock_predictions.get)
print(f"The winning stock is {winning_stock} with a predicted price of ${stock_predictions[winning_stock]:.2f}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 852/852 - 4s - loss: 0.0192 - 4s/epoch - 4ms/step
# Epoch 2/100
# 852/852 - 1s - loss: 8.8762e-04 - 1s/epoch - 2ms/step
# Epoch 3/100
# 852/852 - 2s - loss: 8.6248e-04 - 2s/epoch - 3ms/step
# Epoch 4/100
# 852/852 - 2s - loss: 8.6460e-04 - 2s/epoch - 2ms/step
# Epoch 5/100
# 852/852 - 2s - loss: 8.0994e-04 - 2s/epoch - 2ms/step
# Epoch 6/100
# 852/852 - 1s - loss: 7.5759e-04 - 1s/epoch - 2ms/step
# Epoch 7/100
# 852/852 - 2s - loss: 7.1230e-04 - 2s/epoch - 2ms/step
# Epoch 8/100
# 852/852 - 2s - loss: 6.9046e-04 - 2s/epoch - 2ms/step
# Epoch 9/100
# 852/852 - 1s - loss: 6.7021e-04 - 1s/epoch - 2ms/step
# Epoch 10/100
# 852/852 - 2s - loss: 7.0525e-04 - 2s/epoch - 3ms/step
# Epoch 11/100
# 852/852 - 2s - loss: 6.9387e-04 - 2s/epoch - 3ms/step
# Epoch 12/100
# 852/852 - 2s - loss: 6.6392e-04 - 2s/epoch - 2ms/step
# Epoch 13/100
# 852/852 - 1s - loss: 6.7808e-04 - 1s/epoch - 2ms/step
# Epoch 14/100
# 852/852 - 1s - loss: 6.6032e-04 - 1s/epoch - 2ms/step
# Epoch 15/100
# 852/852 - 2s - loss: 6.6612e-04 - 2s/epoch - 2ms/step
# Epoch 16/100
# 852/852 - 1s - loss: 6.3246e-04 - 1s/epoch - 2ms/step
# Epoch 17/100
# 852/852 - 2s - loss: 6.2066e-04 - 2s/epoch - 2ms/step
# Epoch 18/100
# 852/852 - 2s - loss: 6.2554e-04 - 2s/epoch - 3ms/step
# Epoch 19/100
# 852/852 - 2s - loss: 6.0302e-04 - 2s/epoch - 2ms/step
# Epoch 20/100
# 852/852 - 1s - loss: 6.2864e-04 - 1s/epoch - 2ms/step
# Epoch 21/100
# 852/852 - 1s - loss: 6.1182e-04 - 1s/epoch - 2ms/step
# Epoch 22/100
# 852/852 - 1s - loss: 5.8316e-04 - 1s/epoch - 2ms/step
# Epoch 23/100
# 852/852 - 2s - loss: 5.9229e-04 - 2s/epoch - 2ms/step
# Epoch 24/100
# 852/852 - 2s - loss: 6.0959e-04 - 2s/epoch - 2ms/step
# Epoch 25/100
# 852/852 - 2s - loss: 5.7897e-04 - 2s/epoch - 3ms/step
# Epoch 26/100
# 852/852 - 2s - loss: 6.0623e-04 - 2s/epoch - 2ms/step
# Epoch 27/100
# 852/852 - 1s - loss: 5.9549e-04 - 1s/epoch - 2ms/step
# Epoch 28/100
# 852/852 - 2s - loss: 5.7791e-04 - 2s/epoch - 2ms/step
# Epoch 29/100
# 852/852 - 2s - loss: 5.9054e-04 - 2s/epoch - 2ms/step
# Epoch 30/100
# 852/852 - 2s - loss: 6.2002e-04 - 2s/epoch - 2ms/step
# Epoch 31/100
# 852/852 - 2s - loss: 5.8424e-04 - 2s/epoch - 2ms/step
# Epoch 32/100
# 852/852 - 3s - loss: 5.9793e-04 - 3s/epoch - 3ms/step
# Epoch 33/100
# 852/852 - 2s - loss: 5.9960e-04 - 2s/epoch - 2ms/step
# Epoch 34/100
# 852/852 - 2s - loss: 6.1361e-04 - 2s/epoch - 2ms/step
# Epoch 35/100
# 852/852 - 2s - loss: 6.0159e-04 - 2s/epoch - 2ms/step
# Epoch 36/100
# 852/852 - 2s - loss: 5.9166e-04 - 2s/epoch - 2ms/step
# Epoch 37/100
# 852/852 - 2s - loss: 6.3843e-04 - 2s/epoch - 2ms/step
# Epoch 38/100
# 852/852 - 2s - loss: 5.8667e-04 - 2s/epoch - 2ms/step
# Epoch 39/100
# 852/852 - 2s - loss: 5.7504e-04 - 2s/epoch - 2ms/step
# Epoch 40/100
# 852/852 - 2s - loss: 5.9452e-04 - 2s/epoch - 2ms/step
# Epoch 41/100
# 852/852 - 2s - loss: 6.1731e-04 - 2s/epoch - 2ms/step
# Epoch 42/100
# 852/852 - 2s - loss: 5.8561e-04 - 2s/epoch - 2ms/step
# Epoch 43/100
# 852/852 - 3s - loss: 5.9018e-04 - 3s/epoch - 3ms/step
# Epoch 44/100
# 852/852 - 2s - loss: 5.7755e-04 - 2s/epoch - 3ms/step
# Epoch 45/100
# 852/852 - 2s - loss: 5.5930e-04 - 2s/epoch - 2ms/step
# Epoch 46/100
# 852/852 - 2s - loss: 5.8677e-04 - 2s/epoch - 3ms/step
# Epoch 47/100
# 852/852 - 2s - loss: 5.7666e-04 - 2s/epoch - 2ms/step
# Epoch 48/100
# 852/852 - 2s - loss: 5.7651e-04 - 2s/epoch - 2ms/step
# Epoch 49/100
# 852/852 - 2s - loss: 5.7883e-04 - 2s/epoch - 2ms/step
# Epoch 50/100
# 852/852 - 2s - loss: 5.9458e-04 - 2s/epoch - 2ms/step
# Epoch 51/100
# 852/852 - 2s - loss: 6.0833e-04 - 2s/epoch - 2ms/step
# Epoch 52/100
# 852/852 - 2s - loss: 6.0313e-04 - 2s/epoch - 2ms/step
# Epoch 53/100
# 852/852 - 3s - loss: 5.5888e-04 - 3s/epoch - 3ms/step
# Epoch 54/100
# 852/852 - 2s - loss: 5.7611e-04 - 2s/epoch - 2ms/step
# Epoch 55/100
# 852/852 - 2s - loss: 5.4887e-04 - 2s/epoch - 2ms/step
# Epoch 56/100
# 852/852 - 2s - loss: 5.8013e-04 - 2s/epoch - 2ms/step
# Epoch 57/100
# 852/852 - 2s - loss: 5.9466e-04 - 2s/epoch - 2ms/step
# Epoch 58/100
# 852/852 - 2s - loss: 5.8425e-04 - 2s/epoch - 2ms/step
# Epoch 59/100
# 852/852 - 2s - loss: 5.8221e-04 - 2s/epoch - 2ms/step
# Epoch 60/100
# 852/852 - 2s - loss: 5.4443e-04 - 2s/epoch - 2ms/step
# Epoch 61/100
# 852/852 - 2s - loss: 5.6326e-04 - 2s/epoch - 2ms/step
# Epoch 62/100
# 852/852 - 2s - loss: 5.7773e-04 - 2s/epoch - 2ms/step
# Epoch 63/100
# 852/852 - 2s - loss: 5.4395e-04 - 2s/epoch - 2ms/step
# Epoch 64/100
# 852/852 - 2s - loss: 5.7474e-04 - 2s/epoch - 2ms/step
# Epoch 65/100
# 852/852 - 2s - loss: 5.6188e-04 - 2s/epoch - 2ms/step
# Epoch 66/100
# 852/852 - 2s - loss: 5.7878e-04 - 2s/epoch - 2ms/step
# Epoch 67/100
# 852/852 - 2s - loss: 5.6920e-04 - 2s/epoch - 3ms/step
# Epoch 68/100
# 852/852 - 2s - loss: 5.5941e-04 - 2s/epoch - 2ms/step
# Epoch 69/100
# 852/852 - 2s - loss: 5.6127e-04 - 2s/epoch - 2ms/step
# Epoch 70/100
# 852/852 - 1s - loss: 5.6619e-04 - 1s/epoch - 2ms/step
# Epoch 71/100
# 852/852 - 1s - loss: 5.6944e-04 - 1s/epoch - 2ms/step
# Epoch 72/100
# 852/852 - 1s - loss: 5.7689e-04 - 1s/epoch - 2ms/step
# Epoch 73/100
# 852/852 - 1s - loss: 5.5686e-04 - 1s/epoch - 2ms/step
# Epoch 74/100
# 852/852 - 2s - loss: 5.4612e-04 - 2s/epoch - 2ms/step
# Epoch 75/100
# 852/852 - 2s - loss: 5.6359e-04 - 2s/epoch - 2ms/step
# Epoch 76/100
# 852/852 - 2s - loss: 5.8415e-04 - 2s/epoch - 2ms/step
# Epoch 77/100
# 852/852 - 2s - loss: 5.4257e-04 - 2s/epoch - 2ms/step
# Epoch 78/100
# 852/852 - 2s - loss: 5.4474e-04 - 2s/epoch - 2ms/step
# Epoch 79/100
# 852/852 - 2s - loss: 5.4581e-04 - 2s/epoch - 2ms/step
# Epoch 80/100
# 852/852 - 2s - loss: 5.6077e-04 - 2s/epoch - 2ms/step
# Epoch 81/100
# 852/852 - 2s - loss: 5.7279e-04 - 2s/epoch - 2ms/step
# Epoch 82/100
# 852/852 - 2s - loss: 5.9652e-04 - 2s/epoch - 3ms/step
# Epoch 83/100
# 852/852 - 2s - loss: 5.5439e-04 - 2s/epoch - 2ms/step
# Epoch 84/100
# 852/852 - 2s - loss: 5.5567e-04 - 2s/epoch - 2ms/step
# Epoch 85/100
# 852/852 - 2s - loss: 5.5749e-04 - 2s/epoch - 2ms/step
# Epoch 86/100
# 852/852 - 2s - loss: 5.5104e-04 - 2s/epoch - 2ms/step
# Epoch 87/100
# 852/852 - 2s - loss: 5.5708e-04 - 2s/epoch - 2ms/step
# Epoch 88/100
# 852/852 - 2s - loss: 5.4936e-04 - 2s/epoch - 2ms/step
# Epoch 89/100
# 852/852 - 2s - loss: 5.5786e-04 - 2s/epoch - 3ms/step
# Epoch 90/100
# 852/852 - 2s - loss: 5.7671e-04 - 2s/epoch - 2ms/step
# Epoch 91/100
# 852/852 - 2s - loss: 5.5417e-04 - 2s/epoch - 2ms/step
# Epoch 92/100
# 852/852 - 2s - loss: 5.6901e-04 - 2s/epoch - 2ms/step
# Epoch 93/100
# 852/852 - 2s - loss: 5.4398e-04 - 2s/epoch - 2ms/step
# Epoch 94/100
# 852/852 - 2s - loss: 5.6060e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 852/852 - 2s - loss: 5.5653e-04 - 2s/epoch - 2ms/step
# Epoch 96/100
# 852/852 - 2s - loss: 5.4769e-04 - 2s/epoch - 3ms/step
# Epoch 97/100
# 852/852 - 2s - loss: 5.5894e-04 - 2s/epoch - 2ms/step
# Epoch 98/100
# 852/852 - 1s - loss: 5.7230e-04 - 1s/epoch - 2ms/step
# Epoch 99/100
# 852/852 - 1s - loss: 5.2797e-04 - 1s/epoch - 2ms/step
# Epoch 100/100
# 852/852 - 2s - loss: 5.6940e-04 - 2s/epoch - 2ms/step
# 1/1 [==============================] - 0s 479ms/step
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 852/852 - 3s - loss: 0.0151 - 3s/epoch - 4ms/step
# Epoch 2/100
# 852/852 - 2s - loss: 0.0010 - 2s/epoch - 3ms/step
# Epoch 3/100
# 852/852 - 2s - loss: 9.3119e-04 - 2s/epoch - 2ms/step
# Epoch 4/100
# 852/852 - 2s - loss: 9.1311e-04 - 2s/epoch - 2ms/step
# Epoch 5/100
# 852/852 - 2s - loss: 8.2607e-04 - 2s/epoch - 2ms/step
# Epoch 6/100
# 852/852 - 2s - loss: 7.9431e-04 - 2s/epoch - 2ms/step
# Epoch 7/100
# 852/852 - 1s - loss: 7.6369e-04 - 1s/epoch - 2ms/step
# Epoch 8/100
# 852/852 - 2s - loss: 7.7154e-04 - 2s/epoch - 2ms/step
# Epoch 9/100
# 852/852 - 2s - loss: 7.9372e-04 - 2s/epoch - 2ms/step
# Epoch 10/100
# 852/852 - 2s - loss: 7.0555e-04 - 2s/epoch - 2ms/step
# Epoch 11/100
# 852/852 - 2s - loss: 7.4293e-04 - 2s/epoch - 2ms/step
# Epoch 12/100
# 852/852 - 1s - loss: 6.9487e-04 - 1s/epoch - 2ms/step
# Epoch 13/100
# 852/852 - 2s - loss: 6.9241e-04 - 2s/epoch - 2ms/step
# Epoch 14/100
# 852/852 - 2s - loss: 6.9216e-04 - 2s/epoch - 2ms/step
# Epoch 15/100
# 852/852 - 2s - loss: 7.3747e-04 - 2s/epoch - 2ms/step
# Epoch 16/100
# 852/852 - 2s - loss: 6.7182e-04 - 2s/epoch - 2ms/step
# Epoch 17/100
# 852/852 - 2s - loss: 6.9211e-04 - 2s/epoch - 3ms/step
# Epoch 18/100
# 852/852 - 2s - loss: 6.3063e-04 - 2s/epoch - 2ms/step
# Epoch 19/100
# 852/852 - 2s - loss: 6.7567e-04 - 2s/epoch - 2ms/step
# Epoch 20/100
# 852/852 - 1s - loss: 6.5703e-04 - 1s/epoch - 2ms/step
# Epoch 21/100
# 852/852 - 2s - loss: 6.4361e-04 - 2s/epoch - 2ms/step
# Epoch 22/100
# 852/852 - 2s - loss: 6.3010e-04 - 2s/epoch - 3ms/step
# Epoch 23/100
# 852/852 - 2s - loss: 6.3435e-04 - 2s/epoch - 2ms/step
# Epoch 24/100
# 852/852 - 2s - loss: 6.3347e-04 - 2s/epoch - 3ms/step
# Epoch 25/100
# 852/852 - 2s - loss: 6.2437e-04 - 2s/epoch - 2ms/step
# Epoch 26/100
# 852/852 - 2s - loss: 6.1237e-04 - 2s/epoch - 2ms/step
# Epoch 27/100
# 852/852 - 1s - loss: 6.3170e-04 - 1s/epoch - 2ms/step
# Epoch 28/100
# 852/852 - 2s - loss: 6.3397e-04 - 2s/epoch - 2ms/step
# Epoch 29/100
# 852/852 - 2s - loss: 5.9534e-04 - 2s/epoch - 2ms/step
# Epoch 30/100
# 852/852 - 2s - loss: 6.5374e-04 - 2s/epoch - 2ms/step
# Epoch 31/100
# 852/852 - 2s - loss: 6.2349e-04 - 2s/epoch - 3ms/step
# Epoch 32/100
# 852/852 - 2s - loss: 6.2737e-04 - 2s/epoch - 2ms/step
# Epoch 33/100
# 852/852 - 2s - loss: 6.2203e-04 - 2s/epoch - 2ms/step
# Epoch 34/100
# 852/852 - 2s - loss: 6.4467e-04 - 2s/epoch - 2ms/step
# Epoch 35/100
# 852/852 - 1s - loss: 5.9600e-04 - 1s/epoch - 2ms/step
# Epoch 36/100
# 852/852 - 2s - loss: 6.1569e-04 - 2s/epoch - 2ms/step
# Epoch 37/100
# 852/852 - 1s - loss: 5.9463e-04 - 1s/epoch - 2ms/step
# Epoch 38/100
# 852/852 - 2s - loss: 6.1117e-04 - 2s/epoch - 2ms/step
# Epoch 39/100
# 852/852 - 2s - loss: 5.9566e-04 - 2s/epoch - 3ms/step
# Epoch 40/100
# 852/852 - 2s - loss: 6.1772e-04 - 2s/epoch - 2ms/step
# Epoch 41/100
# 852/852 - 2s - loss: 6.1783e-04 - 2s/epoch - 2ms/step
# Epoch 42/100
# 852/852 - 2s - loss: 6.2722e-04 - 2s/epoch - 2ms/step
# Epoch 43/100
# 852/852 - 2s - loss: 6.0085e-04 - 2s/epoch - 2ms/step
# Epoch 44/100
# 852/852 - 2s - loss: 5.8879e-04 - 2s/epoch - 2ms/step
# Epoch 45/100
# 852/852 - 1s - loss: 6.1507e-04 - 1s/epoch - 2ms/step
# Epoch 46/100
# 852/852 - 2s - loss: 5.7987e-04 - 2s/epoch - 2ms/step
# Epoch 47/100
# 852/852 - 2s - loss: 5.8298e-04 - 2s/epoch - 3ms/step
# Epoch 48/100
# 852/852 - 1s - loss: 5.9969e-04 - 1s/epoch - 2ms/step
# Epoch 49/100
# 852/852 - 1s - loss: 6.2718e-04 - 1s/epoch - 2ms/step
# Epoch 50/100
# 852/852 - 1s - loss: 5.9764e-04 - 1s/epoch - 2ms/step
# Epoch 51/100
# 852/852 - 2s - loss: 6.0651e-04 - 2s/epoch - 2ms/step
# Epoch 52/100
# 852/852 - 2s - loss: 6.1412e-04 - 2s/epoch - 2ms/step
# Epoch 53/100
# 852/852 - 2s - loss: 6.0882e-04 - 2s/epoch - 2ms/step
# Epoch 54/100
# 852/852 - 2s - loss: 5.9115e-04 - 2s/epoch - 3ms/step
# Epoch 55/100
# 852/852 - 2s - loss: 5.9541e-04 - 2s/epoch - 2ms/step
# Epoch 56/100
# 852/852 - 1s - loss: 5.9294e-04 - 1s/epoch - 2ms/step
# Epoch 57/100
# 852/852 - 2s - loss: 6.1081e-04 - 2s/epoch - 2ms/step
# Epoch 58/100
# 852/852 - 1s - loss: 5.9367e-04 - 1s/epoch - 2ms/step
# Epoch 59/100
# 852/852 - 1s - loss: 6.1161e-04 - 1s/epoch - 2ms/step
# Epoch 60/100
# 852/852 - 1s - loss: 5.8293e-04 - 1s/epoch - 2ms/step
# Epoch 61/100
# 852/852 - 2s - loss: 5.8618e-04 - 2s/epoch - 2ms/step
# Epoch 62/100
# 852/852 - 2s - loss: 5.8468e-04 - 2s/epoch - 2ms/step
# Epoch 63/100
# 852/852 - 2s - loss: 5.8075e-04 - 2s/epoch - 2ms/step
# Epoch 64/100
# 852/852 - 2s - loss: 5.9980e-04 - 2s/epoch - 2ms/step
# Epoch 65/100
# 852/852 - 2s - loss: 5.8463e-04 - 2s/epoch - 2ms/step
# Epoch 66/100
# 852/852 - 1s - loss: 6.0146e-04 - 1s/epoch - 2ms/step
# Epoch 67/100
# 852/852 - 1s - loss: 5.8103e-04 - 1s/epoch - 2ms/step
# Epoch 68/100
# 852/852 - 1s - loss: 5.7269e-04 - 1s/epoch - 2ms/step
# Epoch 69/100
# 852/852 - 2s - loss: 5.5735e-04 - 2s/epoch - 2ms/step
# Epoch 70/100
# 852/852 - 2s - loss: 6.0071e-04 - 2s/epoch - 2ms/step
# Epoch 71/100
# 852/852 - 2s - loss: 6.0303e-04 - 2s/epoch - 2ms/step
# Epoch 72/100
# 852/852 - 1s - loss: 5.9334e-04 - 1s/epoch - 2ms/step
# Epoch 73/100
# 852/852 - 2s - loss: 5.8304e-04 - 2s/epoch - 2ms/step
# Epoch 74/100
# 852/852 - 2s - loss: 6.1657e-04 - 2s/epoch - 2ms/step
# Epoch 75/100
# 852/852 - 2s - loss: 6.2592e-04 - 2s/epoch - 2ms/step
# Epoch 76/100
# 852/852 - 1s - loss: 5.8675e-04 - 1s/epoch - 2ms/step
# Epoch 77/100
# 852/852 - 2s - loss: 5.8198e-04 - 2s/epoch - 2ms/step
# Epoch 78/100
# 852/852 - 2s - loss: 5.9338e-04 - 2s/epoch - 2ms/step
# Epoch 79/100
# 852/852 - 2s - loss: 5.7046e-04 - 2s/epoch - 2ms/step
# Epoch 80/100
# 852/852 - 2s - loss: 5.8944e-04 - 2s/epoch - 2ms/step
# Epoch 81/100
# 852/852 - 2s - loss: 5.8138e-04 - 2s/epoch - 2ms/step
# Epoch 82/100
# 852/852 - 2s - loss: 5.9747e-04 - 2s/epoch - 2ms/step
# Epoch 83/100
# 852/852 - 1s - loss: 6.0224e-04 - 1s/epoch - 2ms/step
# Epoch 84/100
# 852/852 - 1s - loss: 5.7841e-04 - 1s/epoch - 2ms/step
# Epoch 85/100
# 852/852 - 2s - loss: 5.8834e-04 - 2s/epoch - 2ms/step
# Epoch 86/100
# 852/852 - 2s - loss: 5.6969e-04 - 2s/epoch - 2ms/step
# Epoch 87/100
# 852/852 - 1s - loss: 5.8940e-04 - 1s/epoch - 2ms/step
# Epoch 88/100
# 852/852 - 2s - loss: 5.9042e-04 - 2s/epoch - 2ms/step
# Epoch 89/100
# 852/852 - 2s - loss: 5.8948e-04 - 2s/epoch - 2ms/step
# Epoch 90/100
# 852/852 - 1s - loss: 5.7951e-04 - 1s/epoch - 2ms/step
# Epoch 91/100
# 852/852 - 2s - loss: 5.7460e-04 - 2s/epoch - 2ms/step
# Epoch 92/100
# 852/852 - 1s - loss: 5.8251e-04 - 1s/epoch - 2ms/step
# Epoch 93/100
# 852/852 - 2s - loss: 5.7328e-04 - 2s/epoch - 2ms/step
# Epoch 94/100
# 852/852 - 2s - loss: 5.9676e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 852/852 - 2s - loss: 5.9625e-04 - 2s/epoch - 2ms/step
# Epoch 96/100
# 852/852 - 1s - loss: 5.9208e-04 - 1s/epoch - 2ms/step
# Epoch 97/100
# 852/852 - 1s - loss: 5.6439e-04 - 1s/epoch - 2ms/step
# Epoch 98/100
# 852/852 - 1s - loss: 6.1000e-04 - 1s/epoch - 2ms/step
# Epoch 99/100
# 852/852 - 1s - loss: 5.6294e-04 - 1s/epoch - 2ms/step
# Epoch 100/100
# 852/852 - 1s - loss: 5.5021e-04 - 1s/epoch - 2ms/step
# 1/1 [==============================] - 1s 594ms/step
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 852/852 - 4s - loss: 0.0154 - 4s/epoch - 4ms/step
# Epoch 2/100
# 852/852 - 2s - loss: 0.0010 - 2s/epoch - 2ms/step
# Epoch 3/100
# 852/852 - 1s - loss: 9.6772e-04 - 1s/epoch - 2ms/step
# Epoch 4/100
# 852/852 - 1s - loss: 9.2177e-04 - 1s/epoch - 2ms/step
# Epoch 5/100
# 852/852 - 2s - loss: 9.1542e-04 - 2s/epoch - 2ms/step
# Epoch 6/100
# 852/852 - 1s - loss: 8.1887e-04 - 1s/epoch - 2ms/step
# Epoch 7/100
# 852/852 - 2s - loss: 8.2014e-04 - 2s/epoch - 2ms/step
# Epoch 8/100
# 852/852 - 2s - loss: 8.1041e-04 - 2s/epoch - 2ms/step
# Epoch 9/100
# 852/852 - 2s - loss: 8.1062e-04 - 2s/epoch - 2ms/step
# Epoch 10/100
# 852/852 - 1s - loss: 7.6042e-04 - 1s/epoch - 2ms/step
# Epoch 11/100
# 852/852 - 1s - loss: 7.5393e-04 - 1s/epoch - 2ms/step
# Epoch 12/100
# 852/852 - 2s - loss: 7.7021e-04 - 2s/epoch - 2ms/step
# Epoch 13/100
# 852/852 - 1s - loss: 7.0439e-04 - 1s/epoch - 2ms/step
# Epoch 14/100
# 852/852 - 1s - loss: 7.2790e-04 - 1s/epoch - 2ms/step
# Epoch 15/100
# 852/852 - 2s - loss: 7.2744e-04 - 2s/epoch - 2ms/step
# Epoch 16/100
# 852/852 - 2s - loss: 6.7375e-04 - 2s/epoch - 2ms/step
# Epoch 17/100
# 852/852 - 2s - loss: 6.9230e-04 - 2s/epoch - 2ms/step
# Epoch 18/100
# 852/852 - 1s - loss: 7.1778e-04 - 1s/epoch - 2ms/step
# Epoch 19/100
# 852/852 - 2s - loss: 7.4599e-04 - 2s/epoch - 2ms/step
# Epoch 20/100
# 852/852 - 1s - loss: 6.9834e-04 - 1s/epoch - 2ms/step
# Epoch 21/100
# 852/852 - 1s - loss: 6.6480e-04 - 1s/epoch - 2ms/step
# Epoch 22/100
# 852/852 - 1s - loss: 7.0338e-04 - 1s/epoch - 2ms/step
# Epoch 23/100
# 852/852 - 2s - loss: 6.7495e-04 - 2s/epoch - 2ms/step
# Epoch 24/100
# 852/852 - 2s - loss: 7.0958e-04 - 2s/epoch - 2ms/step
# Epoch 25/100
# 852/852 - 2s - loss: 6.7924e-04 - 2s/epoch - 2ms/step
# Epoch 26/100
# 852/852 - 1s - loss: 6.7995e-04 - 1s/epoch - 2ms/step
# Epoch 27/100
# 852/852 - 1s - loss: 6.4586e-04 - 1s/epoch - 2ms/step
# Epoch 28/100
# 852/852 - 2s - loss: 7.0540e-04 - 2s/epoch - 2ms/step
# Epoch 29/100
# 852/852 - 2s - loss: 6.5670e-04 - 2s/epoch - 2ms/step
# Epoch 30/100
# 852/852 - 2s - loss: 6.5650e-04 - 2s/epoch - 2ms/step
# Epoch 31/100
# 852/852 - 2s - loss: 6.3156e-04 - 2s/epoch - 2ms/step
# Epoch 32/100
# 852/852 - 2s - loss: 7.0010e-04 - 2s/epoch - 2ms/step
# Epoch 33/100
# 852/852 - 1s - loss: 6.7234e-04 - 1s/epoch - 2ms/step
# Epoch 34/100
# 852/852 - 1s - loss: 6.5867e-04 - 1s/epoch - 2ms/step
# Epoch 35/100
# 852/852 - 1s - loss: 6.4747e-04 - 1s/epoch - 2ms/step
# Epoch 36/100
# 852/852 - 2s - loss: 6.3141e-04 - 2s/epoch - 2ms/step
# Epoch 37/100
# 852/852 - 1s - loss: 6.5076e-04 - 1s/epoch - 2ms/step
# Epoch 38/100
# 852/852 - 1s - loss: 6.6190e-04 - 1s/epoch - 2ms/step
# Epoch 39/100
# 852/852 - 2s - loss: 6.4001e-04 - 2s/epoch - 2ms/step
# Epoch 40/100
# 852/852 - 2s - loss: 6.8128e-04 - 2s/epoch - 2ms/step
# Epoch 41/100
# 852/852 - 1s - loss: 6.6512e-04 - 1s/epoch - 2ms/step
# Epoch 42/100
# 852/852 - 1s - loss: 6.6052e-04 - 1s/epoch - 2ms/step
# Epoch 43/100
# 852/852 - 1s - loss: 6.4288e-04 - 1s/epoch - 2ms/step
# Epoch 44/100
# 852/852 - 2s - loss: 6.4995e-04 - 2s/epoch - 2ms/step
# Epoch 45/100
# 852/852 - 1s - loss: 6.4792e-04 - 1s/epoch - 2ms/step
# Epoch 46/100
# 852/852 - 2s - loss: 6.5489e-04 - 2s/epoch - 2ms/step
# Epoch 47/100
# 852/852 - 2s - loss: 6.5188e-04 - 2s/epoch - 2ms/step
# Epoch 48/100
# 852/852 - 2s - loss: 6.2007e-04 - 2s/epoch - 2ms/step
# Epoch 49/100
# 852/852 - 1s - loss: 6.2528e-04 - 1s/epoch - 2ms/step
# Epoch 50/100
# 852/852 - 1s - loss: 6.6460e-04 - 1s/epoch - 2ms/step
# Epoch 51/100
# 852/852 - 1s - loss: 6.5843e-04 - 1s/epoch - 2ms/step
# Epoch 52/100
# 852/852 - 2s - loss: 6.4080e-04 - 2s/epoch - 2ms/step
# Epoch 53/100
# 852/852 - 2s - loss: 6.5173e-04 - 2s/epoch - 2ms/step
# Epoch 54/100
# 852/852 - 1s - loss: 6.4559e-04 - 1s/epoch - 2ms/step
# Epoch 55/100
# 852/852 - 2s - loss: 6.3191e-04 - 2s/epoch - 2ms/step
# Epoch 56/100
# 852/852 - 2s - loss: 6.3471e-04 - 2s/epoch - 2ms/step
# Epoch 57/100
# 852/852 - 1s - loss: 6.4420e-04 - 1s/epoch - 2ms/step
# Epoch 58/100
# 852/852 - 1s - loss: 6.5181e-04 - 1s/epoch - 2ms/step
# Epoch 59/100
# 852/852 - 1s - loss: 6.2467e-04 - 1s/epoch - 2ms/step
# Epoch 60/100
# 852/852 - 2s - loss: 6.4124e-04 - 2s/epoch - 2ms/step
# Epoch 61/100
# 852/852 - 1s - loss: 6.4864e-04 - 1s/epoch - 2ms/step
# Epoch 62/100
# 852/852 - 2s - loss: 6.3183e-04 - 2s/epoch - 2ms/step
# Epoch 63/100
# 852/852 - 2s - loss: 6.4497e-04 - 2s/epoch - 2ms/step
# Epoch 64/100
# 852/852 - 2s - loss: 6.2594e-04 - 2s/epoch - 2ms/step
# Epoch 65/100
# 852/852 - 1s - loss: 6.1558e-04 - 1s/epoch - 2ms/step
# Epoch 66/100
# 852/852 - 1s - loss: 6.2678e-04 - 1s/epoch - 2ms/step
# Epoch 67/100
# 852/852 - 1s - loss: 6.2670e-04 - 1s/epoch - 2ms/step
# Epoch 68/100
# 852/852 - 1s - loss: 6.3744e-04 - 1s/epoch - 2ms/step
# Epoch 69/100
# 852/852 - 1s - loss: 6.4019e-04 - 1s/epoch - 2ms/step
# Epoch 70/100
# 852/852 - 2s - loss: 6.3946e-04 - 2s/epoch - 2ms/step
# Epoch 71/100
# 852/852 - 2s - loss: 6.4916e-04 - 2s/epoch - 3ms/step
# Epoch 72/100
# 852/852 - 2s - loss: 6.2343e-04 - 2s/epoch - 2ms/step
# Epoch 73/100
# 852/852 - 2s - loss: 6.3712e-04 - 2s/epoch - 2ms/step
# Epoch 74/100
# 852/852 - 2s - loss: 6.2897e-04 - 2s/epoch - 2ms/step
# Epoch 75/100
# 852/852 - 1s - loss: 6.4439e-04 - 1s/epoch - 2ms/step
# Epoch 76/100
# 852/852 - 2s - loss: 6.3613e-04 - 2s/epoch - 2ms/step
# Epoch 77/100
# 852/852 - 1s - loss: 6.4697e-04 - 1s/epoch - 2ms/step
# Epoch 78/100
# 852/852 - 1s - loss: 6.3694e-04 - 1s/epoch - 2ms/step
# Epoch 79/100
# 852/852 - 2s - loss: 6.4401e-04 - 2s/epoch - 2ms/step
# Epoch 80/100
# 852/852 - 2s - loss: 6.3271e-04 - 2s/epoch - 2ms/step
# Epoch 81/100
# 852/852 - 2s - loss: 6.5484e-04 - 2s/epoch - 2ms/step
# Epoch 82/100
# 852/852 - 2s - loss: 6.2975e-04 - 2s/epoch - 2ms/step
# Epoch 83/100
# 852/852 - 2s - loss: 6.2288e-04 - 2s/epoch - 2ms/step
# Epoch 84/100
# 852/852 - 1s - loss: 6.4759e-04 - 1s/epoch - 2ms/step
# Epoch 85/100
# 852/852 - 1s - loss: 6.4537e-04 - 1s/epoch - 2ms/step
# Epoch 86/100
# 852/852 - 2s - loss: 6.2581e-04 - 2s/epoch - 2ms/step
# Epoch 87/100
# 852/852 - 2s - loss: 6.3019e-04 - 2s/epoch - 2ms/step
# Epoch 88/100
# 852/852 - 2s - loss: 6.4952e-04 - 2s/epoch - 2ms/step
# Epoch 89/100
# 852/852 - 2s - loss: 6.2506e-04 - 2s/epoch - 3ms/step
# Epoch 90/100
# 852/852 - 2s - loss: 6.2397e-04 - 2s/epoch - 2ms/step
# Epoch 91/100
# 852/852 - 2s - loss: 6.0948e-04 - 2s/epoch - 2ms/step
# Epoch 92/100
# 852/852 - 2s - loss: 6.5159e-04 - 2s/epoch - 2ms/step
# Epoch 93/100
# 852/852 - 1s - loss: 6.0380e-04 - 1s/epoch - 2ms/step
# Epoch 94/100
# 852/852 - 2s - loss: 6.1916e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 852/852 - 2s - loss: 6.4296e-04 - 2s/epoch - 2ms/step
# Epoch 96/100
# 852/852 - 2s - loss: 6.5479e-04 - 2s/epoch - 2ms/step
# Epoch 97/100
# 852/852 - 1s - loss: 6.1689e-04 - 1s/epoch - 2ms/step
# Epoch 98/100
# 852/852 - 1s - loss: 5.9425e-04 - 1s/epoch - 2ms/step
# Epoch 99/100
# 852/852 - 1s - loss: 6.1114e-04 - 1s/epoch - 2ms/step
# Epoch 100/100
# 852/852 - 2s - loss: 6.1072e-04 - 2s/epoch - 2ms/step
# 1/1 [==============================] - 0s 396ms/step
# The winning stock is MSFT with a predicted price of $326.26
